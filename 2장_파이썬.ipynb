# %% [markdown]
# # 1.2 파이썬과 약속하기

# %% [markdown]
# ## Index

# %%
str = '시작은 0부터'

# %%
str[0]

# %%
str[1]

# %%
str[2]

# %%
str[3]

# %%
str[7]

# %%
str[-1]

# %%
str[-2]

# %%
str[-7]

# %%
123.e-6

# %% [markdown]
# ## 대소문자

# %%
print('맞아요')

# %%
PRINT('맞아요')

# %%
Print('맞아요')

# %%
True

# %%
true

# %% [markdown]
# ## 들여쓰기

# %%
if 2 > 1:
print('맞습니다.')

# %%
if 2 > 1:
    print('맞습니다.')

# %%
if 2 > 1:
    print('맞습니다.')
     print('진짜 맞습니다.')

# %%
if 2 > 1:
    print('맞습니다.')
    print('진짜 맞습니다.')

# %% [markdown]
# # 1.3 데이터 타입 그리고 변수

# %%
123

# %%
'123'

# %%
123.0

# %%
숫자 = 123
문자열 = '123'
부동소수점 = 123.0

# %%
숫자

# %%
문자열

# %%
부동소수점

# %%
print(type(숫자))
print(type(문자열))
print(type(부동소수점))

# %%
숫자 = '1234'
type(숫자)

# %%
문자열 = 1234
type(문자열)

# %% [markdown]
# ## Boolean

# %%
type(True)

# %%
type(False)

# %%
bool(1)

# %%
bool(0)

# %%
bool(0.0)

# %%
bool(100)

# %%
bool('Hi')

# %% [markdown]
# ## Integer

# %%
type(500)

# %%
type(0)

# %%
type(-1000)

# %%
int(-3.2)

# %%
int(3.2)

# %%
int(0.0)

# %%
int(True)

# %%
int(False)

# %%
int('Hi')

# %% [markdown]
# ## Floating Point

# %%
type(3.2)

# %%
type(-3.2)

# %%
type(0.000)

# %%
1e8

# %%
type(1e8)

# %%
123e-6

# %%
float(25)

# %%
float(-100)

# %%
float(0)

# %%
float(True)

# %%
float(False)

# %% [markdown]
# ## String

# %%
'I AM SUPERMAN!'

# %%
"I AM SUPERMAN"

# %%
"""I
AM
SUPERMAN!"""

# %%
'''I
AM
SUPERMAN!'''

# %%
str(True)

# %%
str(20)

# %%
str(-19.94)

# %%
str(12e-4)

# %%
type('True')

# %%
type('1.24')

# %% [markdown]
# ## Tuple

# %%
산 = ('한라산', '지리산', '설악산', '덕유산')
산

# %%
type(산)

# %%
산[1]

# %%
산[-3]

# %% [markdown]
# ## List

# %%
산 = ['한라산', '지리산', '설악산', '덕유산']
산

# %%
type(산)

# %%
산[2]

# %%
산[1:3]

# %%
산[-4]

# %%
산+산

# %%
산*3

# %%
산

# %%
산[2] = '설악산!'
산

# %%
del 산[2]
산

# %%
산.append('태백산')
산

# %%
산.insert(2, '설악산')
산

# %%
산.insert(0, '태백산')
산

# %%
산.count('태백산')

# %%
산.remove('태백산')
산

# %%
산.pop()
산

# %%
산.sort()
산

# %% [markdown]
# ## Dictionary

# %%
산 = {'1등높이':'한라산', '2등높이':'지리산', '3등높이':'설악산', '4등높이':'덕유산'}
산

# %%
type(산)

# %%
산['2등높이']

# %%
산['4등높이']

# %%
산['5등높이'] = '태백산'
산

# %%
산['5등높이'] = '오대산'
산

# %%
산['5등높이'] = '계방산'
산['1등높이'] = '제주한라산'
산

# %%
del 산['2등높이']
del 산['4등높이']
del 산['5등높이']

# %%
산['2등높이'] = '지리산'

# %%
산

# %% [markdown]
# ## Set

# %%
헬로우 = set('hello')
헬로우

# %%
하이 = set(['h', 'i'])
하이

# %%
헬로우.intersection(하이)

# %%
헬로우&하이

# %%
헬로우.union(하이)

# %%
헬로우|하이

# %%
헬로우.difference(하이)

# %%
헬로우-하이

# %%
하이.difference(헬로우)

# %%
하이-헬로우

# %%
헬로우

# %%
헬로우.add('!')
헬로우

# %%
헬로우.update('w', 'o', 'w')
헬로우

# %%
헬로우.remove('w')
헬로우

# %% [markdown]
# # 1.4 연산자

# %% [markdown]
# ## 산술연산자

# %%
2+5

# %%
2-5

# %%
2*5

# %%
2/5

# %%
2//5

# %%
2%5

# %%
2**5

# %% [markdown]
# ## 비교연산자, 논리연산자

# %%
파이썬점수=90
빅데이터개론점수=70

# %%
(파이썬점수>80) and (빅데이터개론점수>80)

# %%
(파이썬점수>70) and (빅데이터개론점수>70)

# %%
(파이썬점수>60) and (빅데이터개론점수>60)

# %%
(파이썬점수>80) or (빅데이터개론점수>80)

# %%
(파이썬점수>90) or (빅데이터개론점수>90)

# %%
not (파이썬점수>90)

# %%
not (파이썬점수>80)

# %% [markdown]
# ## 문자열 가공

# %%
'I ' + 'AM ' + 'SUPERMAN!'
# Out:
# 'I AM SUPERMAN!'

# %%
나 = 'I ' 
는 = 'AM '
슈퍼맨 = 'SUPERMAN!'

나 + 는 + 슈퍼맨
# Out:
# 'I AM SUPERMAN!'

# %%
'-'.join('SUPERMAN!')
# Out:
# 'S-U-P-E-R-M-A-N-!'

# %%
끼어들변수 = '*'
끼어들대상 = 'ABC'

끼어들변수.join(끼어들대상)
# Out:
# 'A*B*C'

# %%
'A'*5
# Out:
# 'AAAAA'

# %%
'Hi~'*3
# Out:
# 'Hi~Hi~Hi~'

# %%
문자열='ABCDEFG'

# %%
문자열[0]
# Out:
# 'A'

# %%
문자열[6]
# Out:
# 'G'

# %%
문자열[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-8bd917c3b738> in <module>
# ----> 1 문자열[7]
#
# IndexError: string index out of range

# %%
문자열[-1]
# Out:
# 'G'

# %%
문자열[-7]
# Out:
# 'A'

# %%
문자열[-8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-b90bdd2ab1e5> in <module>
# ----> 1 문자열[-8]
#
# IndexError: string index out of range

# %%
문자열
# Out:
# 'ABCDEFG'

# %%
문자열[2:5]
# Out:
# 'CDE'

# %%
문자열[::2]
# Out:
# 'ACEG'

# %%
문자열[::3]
# Out:
# 'ADG'

# %%
문자열[4::-2]
# Out:
# 'ECA'

# %%
문자열[6:2:-3]
# Out:
# 'GD'

# %%
len(문자열)
# Out:
# 7

# %%
나도문자열='동해물과 백두산'
len(나도문자열)
# Out:
# 8

# %%
슈퍼맨 = 'I AM SUPERMAN !'
슈퍼맨.split(' ')
# Out:
# ['I', 'AM', 'SUPERMAN', '!']

# %%
휴대폰번호 = '010-1234-5678'
휴대폰번호.split('-')
# Out:
# ['010', '1234', '5678']

# %%
슈퍼맨 = 'I AM SUPERMAN!'
슈퍼맨.replace('SUPERMAN', 'BATMAN')
# Out:
# 'I AM BATMAN!'

# %%
애국가 = '''동해물과 백두산이 마르고 닳도록 
하느님이 보우하사 우리나라 만세 
무궁화 삼천리 화려 강산 
대한 사람 대한으로 길이 보전하세'''

# %%
애국가
# Out:
# '동해물과 백두산이 마르고 닳도록 \n하느님이 보우하사 우리나라 만세 \n무궁화 삼천리 화려 강산 \n대한 사람 대한으로 길이 보전하세'

# %%
애국가.find('우리나라')
# Out:
# 29

# %%
애국가.index('하느님')
# Out:
# 19

# %%
애국가.find('한라산')
# Out:
# -1

# %%
애국가.index('한라산')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-5acd830f4a7d> in <module>
# ----> 1 애국가.index('한라산')
#
# ValueError: substring not found

# %%
애국가.count('대한')
# Out:
# 2

# %%
슈퍼맨 = 'i aM SuperMan!'
슈퍼맨
# Out:
# 'i aM SuperMan!'

# %%
슈퍼맨.capitalize()
# Out:
# 'I am superman!'

# %%
슈퍼맨.title()
# Out:
# 'I Am Superman!'

# %%
슈퍼맨.upper()
# Out:
# 'I AM SUPERMAN!'

# %%
슈퍼맨.lower()
# Out:
# 'i am superman!'
